# %% [markdown]
# # Movies DataFrame

# %%
import pandas as pd

df = pd.read_json('movies.json')
df
# Out:
#                                    title            original_title  score  \
# 0                             Les Évadés  The Shawshank Redemption    9.3
# 1                       Fenêtre sur cour               Rear Window    8.5
# 2                            Le Prestige              The Prestige    8.5
# 3         Il était une fois dans l'Ouest   C'era una volta il West    8.5
# 4                          Les infiltrés              The Departed    8.5
# ..                                   ...                       ...    ...
# 155                La liste de Schindler          Schindler's List    8.9
# 156  The Dark Knight : Le Chevalier noir           The Dark Knight    9.0
# 157                Le Parrain, 2ᵉ partie    The Godfather: Part II    9.0
# 158                           Le Parrain             The Godfather    9.2
# 159                  12 Hommes en colère              12 Angry Men    9.0
#
#                             type  release_date            duration  \
# ...
